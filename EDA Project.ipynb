# %% [markdown]
# ### DESCRIPTIVE STATISTICS
#
# >#### 1. Creating a dataframe using below data:
#
#         Hourly_Income = [1000,2009,24418,444478,324235,243242,3434234,7567457,9235,238237,1312,3412]
#         Hourly_Expense =  [651361,217371,2746,2356,13436,5732,346346,3463,1132,23534,242235,235235]
#         family_members_count = [3,4,2,3,1,4,5,6,3,6,3,5]
#         House_rent = [1299,2300,3411,3422,4566,4211,4600,736,672,0,734,2374]
#         Highest_income_Member = ["Olivia","George","Isla","Harry","Ava","Noah","Sophia","Jacobi","Freddie","Ella","Grace","Ella"]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
dict1 = {'Hourly_Income' : [1000,2009,24418,444478,324235,243242,3434234,7567457,9235,238237,1312,3412],
    'Hourly_Expense' :  [651361,217371,2746,2356,13436,5732,346346,3463,1132,23534,242235,235235],
    'family_members_count' : [3,4,2,3,1,4,5,6,3,6,3,5],
    'House_rent' : [1299,2300,3411,3422,4566,4211,4600,736,672,0,734,2374],
    'Highest_income_Member' : ["Olivia","George","Isla","Harry","Ava","Noah","Sophia","Jacobi","Freddie","Ella","Grace","Ella"]}

df = pd.DataFrame(dict1)
df
# Out:
#     Hourly_Income  Hourly_Expense  family_members_count  House_rent  \
# 0            1000          651361                     3        1299
# 1            2009          217371                     4        2300
# 2           24418            2746                     2        3411
# 3          444478            2356                     3        3422
# 4          324235           13436                     1        4566
# 5          243242            5732                     4        4211
# 6         3434234          346346                     5        4600
# 7         7567457            3463                     6         736
# 8            9235            1132                     3         672
# 9          238237           23534                     6           0
# 10           1312          242235                     3         734
# 11           3412          235235                     5        2374
#
#    Highest_income_Member
# 0                 Olivia
# 1                 George
# ...

# %% [markdown]
#  A) Five Point Summary

# %%
minn,q1,q2, q3, maxx = df.min() ,df.quantile(0.25),df.median(),df.quantile(0.75),df.max()
summary = pd.DataFrame(zip(minn,q1,q2,q3,maxx), columns = ['Min','Q1','Median','Q3','Max'], index = df.select_dtypes(include = np.number).columns)
print('Five Point Summary of the Data is:')
print(summary)
print('\n\n Description of the Data')
print(df.describe())
# Out:
# Five Point Summary of the Data is:
#                        Min       Q1    Median         Q3      Max
# Hourly_Income         1000  3061.25  131327.5  354295.75  7567457
# Hourly_Expense        1132  3283.75   18485.0  236985.00   651361
# family_members_count     1     3.00       3.5       5.00        6
# House_rent               0   735.50    2337.0    3619.25     4600
#
#
#  Description of the Data
#        Hourly_Income  Hourly_Expense  family_members_count   House_rent
# count   1.200000e+01       12.000000             12.000000    12.000000
# mean    1.024439e+06   145412.250000              3.750000  2360.416667
# std     2.274083e+06   202831.565333              1.544786  1661.663813
# min     1.000000e+03     1132.000000              1.000000     0.000000
# 25%     3.061250e+03     3283.750000              3.000000   735.500000
# 50%     1.313275e+05    18485.000000              3.500000  2337.000000
# 75%     3.542958e+05   236985.000000              5.000000  3619.250000
# ...

# %% [markdown]
# B) Mean of Hourly Expense

# %%
df['Hourly_Expense'].mean()
# Out:
# 145412.25

# %% [markdown]
# C) Median of hourly expense

# %%
df['Hourly_Expense'].median()
# Out:
# 18485.0

# %% [markdown]
# D)Find the family member with maximum income and using a suitable graph.

# %%
plt.figure(figsize = (9,8))
ax = sns.barplot(x = 'Highest_income_Member', y = 'Hourly_Income', data  =df)
ax.set_title('Bar Chart for Highest Income')
print('As visible, the member with the highest Income is ', df['Highest_income_Member'][df['Hourly_Income'] == df['Hourly_Income'].max()])
plt.show()
# Out:
# As visible, the member with the highest Income is  7    Jacobi
# Name: Highest_income_Member, dtype: object

# %% [markdown]
# E)Calculating IQR(the difference between 75% and 25% quartile) for Hourly_Income and Hourly_Expense

# %%
IQR1 = summary['Q3']['Hourly_Income'] - summary['Q1']['Hourly_Income']
IQR2 = summary['Q3']['Hourly_Expense'] - summary['Q1']['Hourly_Expense']
pd.Series([IQR1,IQR2], index = ['Hourly_Income', 'Hourly_Expense'])
# Out:
# Hourly_Income     351234.50
# Hourly_Expense    233701.25
# dtype: float64

# %% [markdown]
# F)Calculating the standard deviation for first 2 columns.

# %%
round(df.iloc[:, :2].std(),2)
# Out:
# Hourly_Income     2274082.75
# Hourly_Expense     202831.57
# dtype: float64

# %% [markdown]
# G) Calculating variance for the first 4 columns

# %%
round(df.iloc[:, :4].var(),2)
# Out:
# Hourly_Income           5.171452e+12
# Hourly_Expense          4.114064e+10
# family_members_count    2.390000e+00
# House_rent              2.761127e+06
# dtype: float64

# %% [markdown]
# 2. Preliminary Wrangling

# %%
df1 = pd.read_csv('Pri-Load.csv')
df1.transpose()
# Out:
#                                                     0     \
# ListingCreationDate        2007-08-26 19:09:29.263000000
# Term                                                  36
# LoanStatus                                     Completed
# ClosedDate                               14-08-2009 0.00
# BorrowerAPR                                      0.16516
# BorrowerRate                                       0.158
# LenderYield                                        0.138
# ProsperRating (Alpha)                                NaN
# ProsperScore                                         NaN
# ListingCategory (numeric)                              0
# BorrowerState                                         CO
# Occupation                                         Other
# EmploymentStatus                           Self-employed
# AmountDelinquent                                   472.0
# StatedMonthlyIncome                          3083.333333
# ...

# %% [markdown]
# B. Checking the data type and adjusting datatype for all other categorical columns.

# %%
#df1.transpose()
df1.loc[:, ['Term','LoanStatus','ProsperRating (Alpha)','BorrowerState','Occupation','EmploymentStatus','LoanOriginationQuarter']]
# Out:
#       Term LoanStatus ProsperRating (Alpha) BorrowerState  \
# 0       36  Completed                   NaN            CO
# 1       36    Current                     A            CO
# 2       36  Completed                   NaN            GA
# 3       36    Current                     A            GA
# 4       36    Current                     D            MN
# ...    ...        ...                   ...           ...
# 1030    36    Current                     C            CA
# 1031    60    Current                     C            NJ
# 1032    36  Completed                   NaN            SC
# 1033    60    Current                     D            AK
# 1034    36  Completed                   NaN            TX
#
#                     Occupation EmploymentStatus LoanOriginationQuarter
# 0                        Other    Self-employed                Q3 2007
# 1                 Professional         Employed                Q1 2014
# ...

# %%
df1['Term'] = df1['Term'].astype('object')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ListingCreationDate        1035 non-null   object
#  1   Term                       1035 non-null   object
#  2   LoanStatus                 1035 non-null   object
#  3   ClosedDate                 479 non-null    object
#  4   BorrowerAPR                1035 non-null   float64
#  5   BorrowerRate               1035 non-null   float64
#  6   LenderYield                1035 non-null   float64
#  7   ProsperRating (Alpha)      783 non-null    object
#  8   ProsperScore               783 non-null    float64
#  9   ListingCategory (numeric)  1035 non-null   int64
#  10  BorrowerState              983 non-null    object
#  11  Occupation                 996 non-null    object
#  12  EmploymentStatus           1010 non-null   object
# ...

# %% [markdown]
# C.Finding and dropping of the missing values in the ProsperRating column.

# %%
df1.dropna(subset = ['ProsperRating (Alpha)'], inplace = True)
df1
# Out:
#                 ListingCreationDate  Term LoanStatus       ClosedDate  \
# 1     2014-02-27 08:28:07.900000000    36    Current              NaN
# 3     2012-10-22 11:02:35.010000000    36    Current              NaN
# 4     2013-09-14 18:38:39.097000000    36    Current              NaN
# 5     2013-12-14 08:26:37.093000000    60    Current              NaN
# 6     2013-04-12 09:52:56.147000000    36    Current              NaN
# ...                             ...   ...        ...              ...
# 1028  2010-03-12 12:13:42.697000000    36  Completed  23-03-2013 0.00
# 1029  2013-08-22 13:08:33.250000000    36    Current              NaN
# 1030  2012-02-05 13:26:09.013000000    36    Current              NaN
# 1031  2013-11-30 18:09:55.920000000    60    Current              NaN
# 1033  2011-08-22 21:04:01.433000000    60    Current              NaN
#
#       BorrowerAPR  BorrowerRate  LenderYield ProsperRating (Alpha)  \
# ...

# %% [markdown]
# 3. UNIVARIATE ANALYSIS

# %% [markdown]
# Appling Univariate analysis using suitable charts for[ Loan status, Employment Status, Stated Monthly Income]

# %%
plt.figure(figsize = (25,5))
plt.subplot(1,3,1)
ax1 = sns.lineplot(x = df1.groupby('LoanStatus')['LoanStatus'].count().index, y = df1.groupby('LoanStatus')['LoanStatus'].count().values)
plt.xticks(rotation = 90)
ax1.set_title('Loan Status Line Plot')
ax1.set_ylabel('Count')
plt.subplot(1,3,2)
ax2 = sns.barplot(x = df1.groupby('EmploymentStatus')['EmploymentStatus'].count().index, y = df1.groupby('EmploymentStatus')['EmploymentStatus'].count().values)
ax2.set_title('Employment Status Bar Chart')
ax2.set_ylabel('Count')
plt.xticks(rotation = 90)
plt.subplot(1,3,3)
ax3 = sns.distplot(df1['StatedMonthlyIncome'], color = 'Red')
plt.xticks(rotation = 90)
ax3.set_title('Stated Income Distribution Plot')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Stated Income Distribution Plot')

# %% [markdown]
# Checking if any column distribution skew or not.

# %%
import scipy.stats 
#c = df1['StatedMonthlyIncome'].skew()
c = scipy.stats.skew( df1['StatedMonthlyIncome'])
a = pd.Series(df1.groupby('EmploymentStatus')['EmploymentStatus'].count().values, df1.groupby('EmploymentStatus')['EmploymentStatus'].count().index  ).skew()
b = pd.Series(df1.groupby('LoanStatus')['LoanStatus'].count().values , df1.groupby('LoanStatus')['LoanStatus'].count().index).skew() 

print ('The skewness of the three graphs Loan Status Line Plot , Employment Status Bar Chart , Stated Income Distribution Plot are: ')
pd.Series([a,b,c], index = ['Loan Status Line Plot', 'Employment Status Bar Chart' , 'Stated Income Distribution Plot'])
# Out:
# The skewness of the three graphs Loan Status Line Plot , Employment Status Bar Chart , Stated Income Distribution Plot are:
# Loan Status Line Plot              2.340678
# Employment Status Bar Chart        1.821123
# Stated Income Distribution Plot    3.220408
# dtype: float64

# %% [markdown]
# Two Observations

# %% [markdown]
# Loan Status Line Plot
# - The data has the most frequency at loan status 'Current'. This means that the bank will have to direct extra attention to all the current loans in progressm rather than on loans that have been defaulted, charged off etc.
# - The data is postively skewed and there is a steep drop off from 'Current' to 'Defaulted'. This indicates that the defualt rate it significantly low and the bank must make effore to keep it that way.

# %% [markdown]
# Employment Status Bar Chart
# - As indicated by the data, most of the customers/loan takers are employed. This might give the Bank more ideas to cater to the particular loan needs of an employed individual and create better financial products.
# - The graph indicates that there are only three other employment status's which have a significant amount of customers. They are  Full-Time, Other, and Self-Employed. Since these employment conditions stilll have some significance, the bank must cater their efforts to these individuals as well.

# %% [markdown]
# Stated Incomes Distribution Plot
# - The data is positively skewed and the mode is graphically represented to be clsoe to 5500 to 6000Rs Income.
# - Since the data presents more density at lower income ranges, the bank should cater more of their financial products to the needs of those with lower incomes.

# %% [markdown]
# 4. BIVARIATE ANALYSIS

# %% [markdown]
# A. Checking the correlation matrix for all numeric variables. Maintaining the Strong positive and Negative correlations columns.

# %%
df1.select_dtypes(include = np.number).corr()
# Out:
#                            BorrowerAPR  BorrowerRate  LenderYield  \
# BorrowerAPR                   1.000000      0.989962     0.989498
# BorrowerRate                  0.989962      1.000000     0.998986
# LenderYield                   0.989498      0.998986     1.000000
# ProsperScore                 -0.640320     -0.619934    -0.619934
# ListingCategory (numeric)     0.173637      0.139176     0.141883
# AmountDelinquent              0.029008      0.019442     0.019392
# StatedMonthlyIncome          -0.199210     -0.214624    -0.211835
# LoanCurrentDaysDelinquent     0.108360      0.155858     0.152973
# LoanOriginalAmount           -0.305032     -0.312473    -0.311028
# MonthlyLoanPayment           -0.202339     -0.220645    -0.219325
# LP_InterestandFees            0.176953      0.210123     0.210511
# Investors                    -0.282639     -0.251938    -0.251405
#
#                            ProsperScore  ListingCategory (numeric)  \
# ...

# %%
s = df1.select_dtypes(include = np.number).corr()
c = s.unstack()
corrval = c[c.values !=1] .sort_values()
weak = corrval[0:10]
strong = corrval[-10:]
print('The weak correlations are :')
print(weak)
print('\n\nThe strong correlations are:')
print(strong)
# Out:
# The weak correlations are :
# BorrowerAPR         ProsperScore         -0.640320
# ProsperScore        BorrowerAPR          -0.640320
#                     BorrowerRate         -0.619934
# LenderYield         ProsperScore         -0.619934
# ProsperScore        LenderYield          -0.619934
# BorrowerRate        ProsperScore         -0.619934
#                     LoanOriginalAmount   -0.312473
# LoanOriginalAmount  BorrowerRate         -0.312473
# LenderYield         LoanOriginalAmount   -0.311028
# LoanOriginalAmount  LenderYield          -0.311028
# dtype: float64
#
#
# The strong correlations are:
# LoanOriginalAmount   StatedMonthlyIncome    0.432787
# StatedMonthlyIncome  LoanOriginalAmount     0.432787
# MonthlyLoanPayment   LoanOriginalAmount     0.938081
# LoanOriginalAmount   MonthlyLoanPayment     0.938081
# LenderYield          BorrowerAPR            0.989498
# BorrowerAPR          LenderYield            0.989498
# BorrowerRate         BorrowerAPR            0.989962
# ...

# %% [markdown]
# B. Checking the relation between LoanOriginalAmount and BorrowerAPR columns.

# %%
plt.figure(figsize = (16,6))
plt.subplot(1,2,1)
ax = sns.scatterplot(x = 'LoanOriginalAmount',y = 'BorrowerAPR', data = df1)
ax.set_title('Scatter Plot')

plt.subplot(1,2,2)
ax2 = sns.heatmap(df1[['LoanOriginalAmount','BorrowerAPR']].corr(), data=df1, annot = True, cmap = 'Blues')
ax2.set_title('Heat Map')

plt.tight_layout()

# %% [markdown]
# Observations :
# - LoanOriginal AMount and BorrowerAPR have a slight negative correlation as suggested by the graph. This means that with the rise of one, the other will fall by a small amount.
# - This relationship might not be significant enough for us to draw a conclusion because the scatter plots indicate a significant randomisation of data.

# %% [markdown]
# C.Displaying the seperate box plot for y = BorrowerAPR with x1 = LoanStatus, x2 = EmploymentStatus columns.

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
f=sns.boxplot(x = 'LoanStatus',  y = 'BorrowerAPR',data = df1) 
f.set_title('Loan Status')
plt.xticks(rotation = 90)

plt.subplot(1,2,2)
b = sns.boxplot(x = 'EmploymentStatus',y='BorrowerAPR', data = df1)
b.set_title('Employment Status')
plt.xticks(rotation = 90)
plt.tight_layout()

# %% [markdown]
# Observations :
# - As visible, the dispersion of BorrowerAPR is more steady in the groups of Employment status as compared to the groups of Loan Status. The median of BorroweAPR is relatively the same for most of the groups of Employment Status. This indicates, that Employment Status must not have a big impact on the Borrowe Apr.
# - It is visible that the Loan Status does make an impact on the dispersion of the Borrowe APR. This makes logical sense as LoanStatus does impact the APR with relation to risk management.

# %% [markdown]
# 5.  MULTI VARIATE ANALYSIS, FEATURE ENGINEERING

# %% [markdown]
# Writing a program to change the features of the LoanStatus Column

# %%
condition = (df1['LoanStatus'] == 'Completed') | (df1['LoanStatus'] == 'Defaulted') | (df1['LoanStatus'] == 'Chargedoff')
#condition.value_counts()
#def usdf(x):
#for i,j in zip(df1['LoanStatus'], condition):
#    if ((j == True) & (i == 'Completed')):
#        continue
#    elif ((j== True)& (i == 'Defaulted')):
#        continue
#    elif ((j == True) & (i == 'Chargedoff')):
#        print (i)   
         
#    else:
#        continue
#for i in df1['LoanStatus']:
#    if (i == 'Chargedoff'):
#        i = 'Defaulted'
df1['LoanStatus'].replace('Chargedoff','Defaulted',regex = True, inplace = True)       
#df1['LoanStatus'] =  df1['LoanStatus'].apply(usdf)
#df1['LoanStatus'].value_counts()
df1['LoanStatus']
# Out:
# 0       Completed
# 1         Current
# 2       Completed
# 3         Current
# 4         Current
#           ...
# 1030      Current
# 1031      Current
# 1032    Completed
# 1033      Current
# 1034    Completed
# Name: LoanStatus, Length: 1035, dtype: object

# %%
df1['LoanStatus'].value_counts()
# Out:
# Current                  544
# Completed                332
# Defaulted                146
# Past Due (1-15 days)       5
# Past Due (61-90 days)      4
# Past Due (16-30 days)      2
# Cancelled                  1
# Past Due (31-60 days)      1
# Name: LoanStatus, dtype: int64

# %% [markdown]
# B. Writing a program to feature engineer the ListingCatgoryColumn to make ot easier to analyse.

# %%
categories = {1: 'Debt Consolidation', 2: 'Home Improvement', 3: 'Business', 6: 'Auto', 7: 'Other'}
def allocation(x , categories):
    x['ListingCategory (numeric)'] = x['ListingCategory (numeric)'].map(categories)
    
allocation(df1, categories)
df1.groupby('ListingCategory (numeric)')['ListingCategory (numeric)'].count()
# Out:
# ListingCategory (numeric)
# Auto                   23
# Business               54
# Debt Consolidation    525
# Home Improvement       74
# Other                  93
# Name: ListingCategory (numeric), dtype: int64

# %% [markdown]
# C. Displaying the box plot for ProsperRating (Alpha) vs LoanOriginalAmount and hue = Loan Status[Completed,Defaulted].

# %%
sns.boxplot(x = 'ProsperRating (Alpha)', y = 'LoanOriginalAmount', hue = 'LoanStatus', data = df1[(df1['LoanStatus'] == 'Completed') | (df1['LoanStatus'] == 'Defaulted')]    )
# Out:
# <AxesSubplot:xlabel='ProsperRating (Alpha)', ylabel='LoanOriginalAmount'>

# %% [markdown]
# Observations :

# %% [markdown]
# D. Displaying the catplot for ProsperRating (Alpha) vs ListingCategory (numeric)[Debt Consolidation,Other,Business,Home Improvement,Auto] and hue = Loan Status[Completed,Defaulted]. Write your observations.

# %%
plt.figure(figsize = (20,20))
pd.crosstab(index = df1['ListingCategory (numeric)'], columns = df1['ProsperRating (Alpha)'])
sns.catplot(x = 'ListingCategory (numeric)', y = 'ProsperRating (Alpha)',hue = 'LoanStatus', data = df1[(df1['LoanStatus'] == 'Completed') | (df1['LoanStatus'] == 'Defaulted')])
plt.xticks(rotation = 90)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Debt Consolidation'),
#   Text(1, 0, 'Other'),
#   Text(2, 0, 'Auto'),
#   Text(3, 0, 'Business'),
#   Text(4, 0, 'Home Improvement')])

# %% [markdown]
# Obervations:
# - The difference in the amount of hue foor completed versus that for defaulted is very obviously visible.
# - It is also evident that the relative presense of defaulted loans reduces as we move up grades, indicating once again that better the proper-rating better the quality and assurance of the loan reciever.
# - It is also visible that overall, Debt consolidation seeems to be having the highest amount of Default rates as compared to other listing categories. This could be for a number of reasons such as - Less Leveraged position (not able to raise or pay interest on debt) - riskier markets and fluctuation interest rates - inability to pay back debt due to various ciris (pandemic)
